# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.plot([0,2,4,1],[3,1,7,4],color="lightcoral",linewidth=6,alpha=0.5,marker="o",markersize=15,markeredgewidth=3,markeredgecolor="navy",markerfacecolor="teal")
plt.xlabel("$x(cm^2)$")
plt.ylabel("$Intencidad(\mu)$")
plt.title("Experimento N°1")
plt.grid(True)
plt.show()

# %%
x=np.arange(0,2*np.pi,0.1)
x
y=np.sin(4*x)
y2=np.cos(2*x)
y
plt.plot(x,y,color="hotpink")
plt.plot(x,y2,color="navy",dashes=[4,3])
plt.title("Función seno de (4x) 0-$2\pi$")
plt.grid(True)
plt.xlabel("t(seg)")
plt.ylabel("Amplitud de onda")
plt.show()n

# %%
x=np.random.rand(100)*10
y=np.random.rand(100)*10
r=np.random.rand(100)*250+50
plt.scatter(x,y,s=r,color="pink")
plt.show()

# %%
x=np.random.randn(10000)
plt.hist(x,bins=50,facecolor="skyblue",edgecolor="pink",density=True)
plt.title("Distribución de la población")
plt.ylabel("Densidad habitantes /$m^2$")
plt.text(-3, .35, r'$\mu=100, \ \sigma=1.0$')
plt.show()
